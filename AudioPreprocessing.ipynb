# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
import librosa
import numpy as np
import soundfile as sf  # For saving the modified audio

def process_audio(file_path, output_path, stretch_rate=1.0, pitch_shift_steps=0, noise_level=0.0):
    # Load the audio file
    y, sr = librosa.load(file_path, sr=None)  # Load with original sample rate

    # Time Stretching
    if stretch_rate != 1.0:
        y = librosa.effects.time_stretch(y, rate=stretch_rate)  # Use 'rate' keyword argument



    # Adding Noise
    if noise_level > 0.0:
        noise = np.random.randn(len(y)) * noise_level  # Generate Gaussian noise
        y = y + noise  # Add noise to the audio signal

    # Save the processed audio
    sf.write(output_path, y, sr)

def process_audio_folder(input_folder, output_folder, stretch_rate=1.0, noise_level=0.0):
    # Create the output folder if it does not exist
    os.makedirs(output_folder, exist_ok=True)

    # Process each audio file in the input folder
    for filename in os.listdir(input_folder):
        if filename.endswith('.wav'):  # Process only WAV files
            input_file_path = os.path.join(input_folder, filename)
            output_file_path = os.path.join(output_folder, f'processed_{filename}')
            process_audio(input_file_path, output_file_path, stretch_rate,  noise_level)
            print(f'Processed {filename} and saved to {output_file_path}')

# Example usage
input_folder = '/content/drive/MyDrive/Asthma Detection Dataset Version 2/Bronchial'  # Path to your input audio folder
output_folder = '/content/drive/MyDrive/preprocessAudio/Bronchial'  # Path to save the processed audio

# Process all audio files in the input folder with desired parameters
process_audio_folder(input_folder, output_folder, stretch_rate=1.5, noise_level=0.005)
# Out:
# Processed P13BronchialTc_65.wav and saved to /content/drive/MyDrive/preprocessAudio/Bronchial/processed_P13BronchialTc_65.wav
# Processed P11BronchialSc_54.wav and saved to /content/drive/MyDrive/preprocessAudio/Bronchial/processed_P11BronchialSc_54.wav
# Processed P12BronchialSc_58.wav and saved to /content/drive/MyDrive/preprocessAudio/Bronchial/processed_P12BronchialSc_58.wav
# Processed P11BronchialTc_53.wav and saved to /content/drive/MyDrive/preprocessAudio/Bronchial/processed_P11BronchialTc_53.wav
# Processed P10BronchialTc_49.wav and saved to /content/drive/MyDrive/preprocessAudio/Bronchial/processed_P10BronchialTc_49.wav
# Processed P13BronchialSc_64.wav and saved to /content/drive/MyDrive/preprocessAudio/Bronchial/processed_P13BronchialSc_64.wav
# Processed P10BronchialSc_46.wav and saved to /content/drive/MyDrive/preprocessAudio/Bronchial/processed_P10BronchialSc_46.wav
# Processed P10BronchialSc_50.wav and saved to /content/drive/MyDrive/preprocessAudio/Bronchial/processed_P10BronchialSc_50.wav
# Processed P15BronchialSc_72.wav and saved to /content/drive/MyDrive/preprocessAudio/Bronchial/processed_P15BronchialSc_72.wav
# Processed P14BronchialSc_68.wav and saved to /content/drive/MyDrive/preprocessAudio/Bronchial/processed_P14BronchialSc_68.wav
# Processed P12BronchialSc_56.wav and saved to /content/drive/MyDrive/preprocessAudio/Bronchial/processed_P12BronchialSc_56.wav
# Processed P10BronchialSc_48.wav and saved to /content/drive/MyDrive/preprocessAudio/Bronchial/processed_P10BronchialSc_48.wav
# Processed P13BronchialSc_62.wav and saved to /content/drive/MyDrive/preprocessAudio/Bronchial/processed_P13BronchialSc_62.wav
# Processed P14BronchialTc_67.wav and saved to /content/drive/MyDrive/preprocessAudio/Bronchial/processed_P14BronchialTc_67.wav
# Processed P10BronchialTc_47.wav and saved to /content/drive/MyDrive/preprocessAudio/Bronchial/processed_P10BronchialTc_47.wav
# Processed P13BronchialTc_63.wav and saved to /content/drive/MyDrive/preprocessAudio/Bronchial/processed_P13BronchialTc_63.wav
# Processed P12BronchialTc_57.wav and saved to /content/drive/MyDrive/preprocessAudio/Bronchial/processed_P12BronchialTc_57.wav
# Processed P14BronchialSc_70.wav and saved to /content/drive/MyDrive/preprocessAudio/Bronchial/processed_P14BronchialSc_70.wav
# Processed P14BronchialTc_69.wav and saved to /content/drive/MyDrive/preprocessAudio/Bronchial/processed_P14BronchialTc_69.wav
# Processed P11BronchialTc_51.wav and saved to /content/drive/MyDrive/preprocessAudio/Bronchial/processed_P11BronchialTc_51.wav
# Processed P14BronchialSc_66.wav and saved to /content/drive/MyDrive/preprocessAudio/Bronchial/processed_P14BronchialSc_66.wav
# Processed P12BronchialTc_59.wav and saved to /content/drive/MyDrive/preprocessAudio/Bronchial/processed_P12BronchialTc_59.wav
# Processed P11BronchialSc_52.wav and saved to /content/drive/MyDrive/preprocessAudio/Bronchial/processed_P11BronchialSc_52.wav
# Processed P11BronchialTc_55.wav and saved to /content/drive/MyDrive/preprocessAudio/Bronchial/processed_P11BronchialTc_55.wav
# Processed P13BronchialTc_61.wav and saved to /content/drive/MyDrive/preprocessAudio/Bronchial/processed_P13BronchialTc_61.wav
# Processed P12BronchialSc_60.wav and saved to /content/drive/MyDrive/preprocessAudio/Bronchial/processed_P12BronchialSc_60.wav
# Processed P15BronchialTc_73.wav and saved to /content/drive/MyDrive/preprocessAudio/Bronchial/processed_P15BronchialTc_73.wav
# Processed P20BronchialSc_100.wav and saved to /content/drive/MyDrive/preprocessAudio/Bronchial/processed_P20BronchialSc_100.wav
# Processed P15BronchialTc_71.wav and saved to /content/drive/MyDrive/preprocessAudio/Bronchial/processed_
wav and saved to /content/drive/MyDrive/preprocessAudio/Bronchial/processed_P8BronchialSc_36.wav
# Processed P9BronchialSc_44.wav and saved to /content/drive/MyDrive/preprocessAudio/Bronchial/processed_P9BronchialSc_44.wav
# Processed P7BronchialTc_35.wav and saved to /content/drive/MyDrive/preprocessAudio/Bronchial/processed_P7BronchialTc_35.wav
# Processed P9BronchialSc_42.wav and saved to /content/drive/MyDrive/preprocessAudio/Bronchial/processed_P9BronchialSc_42.wav
# Processed P7BronchialSc_32.wav and saved to /content/drive/MyDrive/preprocessAudio/Bronchial/processed_P7BronchialSc_32.wav
# Processed P6BronchialTc_29.wav and saved to /content/drive/MyDrive/preprocessAudio/Bronchial/processed_P6BronchialTc_29.wav
# Processed P2BronchialSc_10.wav and saved to /content/drive/MyDrive/preprocessAudio/Bronchial/processed_P2BronchialSc_10.wav
# Processed P9BronchialTc_43.wav and saved to /content/drive/MyDrive/preprocessAudio/Bronchial/processed_P9BronchialTc_43.wav
# Processed P3BronchialTc_15.wav and saved to /content/drive/MyDrive/preprocessAudio/Bronchial/processed_P3BronchialTc_15.wav
# Processed P8BronchialSc_38.wav and saved to /content/drive/MyDrive/preprocessAudio/Bronchial/processed_P8BronchialSc_38.wav
# Processed P5BronchialTc_25.wav and saved to /content/drive/MyDrive/preprocessAudio/Bronchial/processed_P5BronchialTc_25.wav
# Processed P8BronchialTc_37.wav and saved to /content/drive/MyDrive/preprocessAudio/Bronchial/processed_P8BronchialTc_37.wav
# Processed P8BronchialTc_39.wav and saved to /content/drive/MyDrive/preprocessAudio/Bronchial/processed_P8BronchialTc_39.wav
# Processed P2BronchialTc_9.wav and saved to /content/drive/MyDrive/preprocessAudio/Bronchial/processed_P2BronchialTc_9.wav
# Processed P4BronchialTc_19.wav and saved to /content/drive/MyDrive/preprocessAudio/Bronchial/processed_P4BronchialTc_19.wav
# Processed P3BronchialTc_13.wav and saved to /content/drive/MyDrive/preprocessAudio/Bronchial/processed_P3BronchialTc_13.wav
# Processed P21BronchialTc_103.wav and saved to /content/drive/MyDrive/preprocessAudio/Bronchial/processed_P21BronchialTc_103.wav
# Processed P6BronchialSc_26.wav and saved to /content/drive/MyDrive/preprocessAudio/Bronchial/processed_P6BronchialSc_26.wav
# Processed P2BronchialSc_6.wav and saved to /content/drive/MyDrive/preprocessAudio/Bronchial/processed_P2BronchialSc_6.wav
# Processed P2BronchialTc_7.wav and saved to /content/drive/MyDrive/preprocessAudio/Bronchial/processed_P2BronchialTc_7.wav
# Processed P9BronchialTc_45.wav and saved to /content/drive/MyDrive/preprocessAudio/Bronchial/processed_P9BronchialTc_45.wav
# Processed P7BronchialTc_33.wav and saved to /content/drive/MyDrive/preprocessAudio/Bronchial/processed_P7BronchialTc_33.wav
# Processed P7BronchialSc_34.wav and saved to /content/drive/MyDrive/preprocessAudio/Bronchial/processed_P7BronchialSc_34.wav
# Processed P3BronchialSc_14.wav and saved to /content/drive/MyDrive/preprocessAudio/Bronchial/processed_P3BronchialSc_14.wav

# %%
import os
import librosa
import numpy as np
import soundfile as sf  # For saving the modified audio

def process_audio(file_path, output_path, stretch_rate=1.0, pitch_shift_steps=0, noise_level=0.0):
    # Load the audio file
    y, sr = librosa.load(file_path, sr=None)  # Load with original sample rate

    # Time Stretching
    if stretch_rate != 1.0:
        y = librosa.effects.time_stretch(y, rate=stretch_rate)  # Use 'rate' keyword argument



    # Adding Noise
    if noise_level > 0.0:
        noise = np.random.randn(len(y)) * noise_level  # Generate Gaussian noise
        y = y + noise  # Add noise to the audio signal

    # Save the processed audio
    sf.write(output_path, y, sr)

def process_audio_folder(input_folder, output_folder, stretch_rate=1.0, noise_level=0.0):
    # Create the output folder if it does not exist
    os.makedirs(output_folder, exist_ok=True)

    # Process each audio file in the input folder
    for filename in os.listdir(input_folder):
        if filename.endswith('.wav'):  # Process only WAV files
            input_file_path = os.path.join(input_folder, filename)
            output_file_path = os.path.join(output_folder, f'processed_{filename}')
            process_audio(input_file_path, output_file_path, stretch_rate,  noise_level)
            print(f'Processed {filename} and saved to {output_file_path}')

# Example usage
input_folder = '/content/drive/MyDrive/Asthma Detection Dataset Version 2/asthma'  # Path to your input audio folder
output_folder = '/content/drive/MyDrive/preprocessAudio/asthma'  # Path to save the processed audio

# Process all audio files in the input folder with desired parameters
process_audio_folder(input_folder, output_folder, stretch_rate=1.5, noise_level=0.005)
# Out:
# Processed P22WheezingIU_106.wav and saved to /content/drive/MyDrive/preprocessAudio/asthma/processed_P22WheezingIU_106.wav
# Processed P14WheezingIE_69.wav and saved to /content/drive/MyDrive/preprocessAudio/asthma/processed_P14WheezingIE_69.wav
# Processed P29WheezingRL_143.wav and saved to /content/drive/MyDrive/preprocessAudio/asthma/processed_P29WheezingRL_143.wav
# Processed P34WheezingIE_169.wav and saved to /content/drive/MyDrive/preprocessAudio/asthma/processed_
wav and saved to /content/drive/MyDrive/preprocessAudio/asthma/processed_P52WheezingIE_257.wav
# Processed P54WheezingIU_270.wav and saved to /content/drive/MyDrive/preprocessAudio/asthma/processed_P54WheezingIU_270.wav
# Processed P7AsthmaRL_35.wav and saved to /content/drive/MyDrive/preprocessAudio/asthma/processed_P7AsthmaRL_35.wav
# Processed P55WheezingRL_271.wav and saved to /content/drive/MyDrive/preprocessAudio/asthma/processed_P55WheezingRL_271.wav
# Processed P9AsthmaIE_45.wav and saved to /content/drive/MyDrive/preprocessAudio/asthma/processed_P9AsthmaIE_45.wav
# Processed P9AsthmaIU_42.wav and saved to /content/drive/MyDrive/preprocessAudio/asthma/processed_P9AsthmaIU_42.wav
# Processed P37WheezingIU_182.wav and saved to /content/drive/MyDrive/preprocessAudio/asthma/processed_P37WheezingIU_182.wav
# Processed P51WheezingRL_251.wav and saved to /content/drive/MyDrive/preprocessAudio/asthma/processed_P51WheezingRL_251.wav
# Processed P8AsthmaIE_37.wav and saved to /content/drive/MyDrive/preprocessAudio/asthma/processed_P8AsthmaIE_37.wav
# Processed P50WheezingIU_246.wav and saved to /content/drive/MyDrive/preprocessAudio/asthma/processed_P50WheezingIU_246.wav
# Processed P41WheezingIU_202.wav and saved to /content/drive/MyDrive/preprocessAudio/asthma/processed_P41WheezingIU_202.wav
# Processed P3AsthmaRL_11.wav and saved to /content/drive/MyDrive/preprocessAudio/asthma/processed_P3AsthmaRL_11.wav
# Processed P43WheezingIE_213.wav and saved to /content/drive/MyDrive/preprocessAudio/asthma/processed_P43WheezingIE_213.wav
# Processed P39WheezingRL_191.wav and saved to /content/drive/MyDrive/preprocessAudio/asthma/processed_P39WheezingRL_191.wav
# Processed P3AsthmaIU_14.wav and saved to /content/drive/MyDrive/preprocessAudio/asthma/processed_P3AsthmaIU_14.wav
# Processed P54WheezingRS_268.wav and saved to /content/drive/MyDrive/preprocessAudio/asthma/processed_P54WheezingRS_268.wav
# Processed P38WheezingIU_190.wav and saved to /content/drive/MyDrive/preprocessAudio/asthma/processed_P38WheezingIU_190.wav
# Processed P4AsthmaIE_17.wav and saved to /content/drive/MyDrive/preprocessAudio/asthma/processed_P4AsthmaIE_17.wav
# Processed P45WheezingIE_221.wav and saved to /content/drive/MyDrive/preprocessAudio/asthma/processed_P45WheezingIE_221.wav
# Processed P9AsthmaIE_41.wav and saved to /content/drive/MyDrive/preprocessAudio/asthma/processed_P9AsthmaIE_41.wav
# Processed P50WheezingRS_248.wav and saved to /content/drive/MyDrive/preprocessAudio/asthma/processed_P50WheezingRS_248.wav
# Processed P37WheezingRL_183.wav and saved to /content/drive/MyDrive/preprocessAudio/asthma/processed_P37WheezingRL_183.wav
# Processed P48WheezingRS_240.wav and saved to /content/drive/MyDrive/preprocessAudio/asthma/processed_P48WheezingRS_240.wav
# Processed P5AsthmaIE_21.wav and saved to /content/drive/MyDrive/preprocessAudio/asthma/processed_P5AsthmaIE_21.wav
# Processed P39WheezingIU_194.wav and saved to /content/drive/MyDrive/preprocessAudio/asthma/processed_P39WheezingIU_194.wav
# Processed P7AsthmaRL_31.wav and saved to /content/drive/MyDrive/preprocessAudio/asthma/processed_P7AsthmaRL_31.wav
# Processed P50WheezingIE_249.wav and saved to /content/drive/MyDrive/preprocessAudio/asthma/processed_P50WheezingIE_249.wav
# Processed P56WheezingRL_279.wav and saved to /content/drive/MyDrive/preprocessAudio/asthma/processed_P56WheezingRL_279.wav
# Processed P44WheezingRL_219.wav and saved to /content/drive/MyDrive/preprocessAudio/asthma/processed_P44WheezingRL_219.wav
# Processed P47WheezingRL_235.wav and saved to /content/drive/MyDrive/preprocessAudio/asthma/processed_P47WheezingRL_235.wav
# Processed P45WheezingIU_222.wav and saved to /content/drive/MyDrive/preprocessAudio/asthma/processed_P45WheezingIU_222.wav
# Processed P52WheezingRL_259.wav and saved to /content/drive/MyDrive/preprocessAudio/asthma/processed_P52WheezingRL_259.wav

# %%
import os
import librosa
import numpy as np
import soundfile as sf  # For saving the modified audio

def process_audio(file_path, output_path, stretch_rate=1.0, pitch_shift_steps=0, noise_level=0.0):
    # Load the audio file
    y, sr = librosa.load(file_path, sr=None)  # Load with original sample rate

    # Time Stretching
    if stretch_rate != 1.0:
        y = librosa.effects.time_stretch(y, rate=stretch_rate)  # Use 'rate' keyword argument



    # Adding Noise
    if noise_level > 0.0:
        noise = np.random.randn(len(y)) * noise_level  # Generate Gaussian noise
        y = y + noise  # Add noise to the audio signal

    # Save the processed audio
    sf.write(output_path, y, sr)

def process_audio_folder(input_folder, output_folder, stretch_rate=1.0, noise_level=0.0):
    # Create the output folder if it does not exist
    os.makedirs(output_folder, exist_ok=True)

    # Process each audio file in the input folder
    for filename in os.listdir(input_folder):
        if filename.endswith('.wav'):  # Process only WAV files
            input_file_path = os.path.join(input_folder, filename)
            output_file_path = os.path.join(output_folder, f'processed_{filename}')
            process_audio(input_file_path, output_file_path, stretch_rate,  noise_level)
            print(f'Processed {filename} and saved to {output_file_path}')

# Example usage
input_folder = '/content/drive/MyDrive/Asthma Detection Dataset Version 2/copd'  # Path to your input audio folder
output_folder = '/content/drive/MyDrive/preprocessAudio/copd'  # Path to save the processed audio

# Process all audio files in the input folder with desired parameters
process_audio_folder(input_folder, output_folder, stretch_rate=1.5, noise_level=0.005)
# Out:
# Processed P10COPDMc_78.wav and saved to /content/drive/MyDrive/preprocessAudio/copd/processed_
wav and saved to /content/drive/MyDrive/preprocessAudio/copd/processed_P8COPDMc_64.wav
# Processed P50COPDMc_396.wav and saved to /content/drive/MyDrive/preprocessAudio/copd/processed_P50COPDMc_396.wav
# Processed P4COPDMc_30.wav and saved to /content/drive/MyDrive/preprocessAudio/copd/processed_P4COPDMc_30.wav
# Processed P8COPDPr_57.wav and saved to /content/drive/MyDrive/preprocessAudio/copd/processed_P8COPDPr_57.wav
# Processed P8COPDPr_61.wav and saved to /content/drive/MyDrive/preprocessAudio/copd/processed_P8COPDPr_61.wav
# Processed P5COPDPr_35.wav and saved to /content/drive/MyDrive/preprocessAudio/copd/processed_P5COPDPr_35.wav
# Processed P5COPDPr_39.wav and saved to /content/drive/MyDrive/preprocessAudio/copd/processed_P5COPDPr_39.wav
# Processed P9COPDPr_69.wav and saved to /content/drive/MyDrive/preprocessAudio/copd/processed_P9COPDPr_69.wav
# Processed P9COPDMc_66.wav and saved to /content/drive/MyDrive/preprocessAudio/copd/processed_P9COPDMc_66.wav
# Processed P8COPDMc_60.wav and saved to /content/drive/MyDrive/preprocessAudio/copd/processed_P8COPDMc_60.wav
# Processed P4COPDPr_31.wav and saved to /content/drive/MyDrive/preprocessAudio/copd/processed_P4COPDPr_31.wav
# Processed P50COPDPr_397.wav and saved to /content/drive/MyDrive/preprocessAudio/copd/processed_P50COPDPr_397.wav
# Processed P7COPDPr_51.wav and saved to /content/drive/MyDrive/preprocessAudio/copd/processed_P7COPDPr_51.wav
# Processed P4COPDMc_32.wav and saved to /content/drive/MyDrive/preprocessAudio/copd/processed_P4COPDMc_32.wav
# Processed P4COPDPr_27.wav and saved to /content/drive/MyDrive/preprocessAudio/copd/processed_P4COPDPr_27.wav
# Processed P8COPDMc_62.wav and saved to /content/drive/MyDrive/preprocessAudio/copd/processed_P8COPDMc_62.wav
# Processed P6COPDPr_43.wav and saved to /content/drive/MyDrive/preprocessAudio/copd/processed_P6COPDPr_43.wav
# Processed P6COPDPr_47.wav and saved to /content/drive/MyDrive/preprocessAudio/copd/processed_P6COPDPr_47.wav
# Processed P4COPDMc_28.wav and saved to /content/drive/MyDrive/preprocessAudio/copd/processed_P4COPDMc_28.wav
# Processed P5COPDMc_34.wav and saved to /content/drive/MyDrive/preprocessAudio/copd/processed_P5COPDMc_34.wav
# Processed P6COPDPr_41.wav and saved to /content/drive/MyDrive/preprocessAudio/copd/processed_P6COPDPr_41.wav
# Processed P9COPDMc_68.wav and saved to /content/drive/MyDrive/preprocessAudio/copd/processed_P9COPDMc_68.wav
# Processed P8COPDPr_59.wav and saved to /content/drive/MyDrive/preprocessAudio/copd/processed_P8COPDPr_59.wav

# %%
import os
import librosa
import numpy as np
import soundfile as sf  # For saving the modified audio

def process_audio(file_path, output_path, stretch_rate=1.0, pitch_shift_steps=0, noise_level=0.0):
    # Load the audio file
    y, sr = librosa.load(file_path, sr=None)  # Load with original sample rate

    # Time Stretching
    if stretch_rate != 1.0:
        y = librosa.effects.time_stretch(y, rate=stretch_rate)  # Use 'rate' keyword argument



    # Adding Noise
    if noise_level > 0.0:
        noise = np.random.randn(len(y)) * noise_level  # Generate Gaussian noise
        y = y + noise  # Add noise to the audio signal

    # Save the processed audio
    sf.write(output_path, y, sr)

def process_audio_folder(input_folder, output_folder, stretch_rate=1.0, noise_level=0.0):
    # Create the output folder if it does not exist
    os.makedirs(output_folder, exist_ok=True)

    # Process each audio file in the input folder
    for filename in os.listdir(input_folder):
        if filename.endswith('.wav'):  # Process only WAV files
            input_file_path = os.path.join(input_folder, filename)
            output_file_path = os.path.join(output_folder, f'processed_{filename}')
            process_audio(input_file_path, output_file_path, stretch_rate,  noise_level)
            print(f'Processed {filename} and saved to {output_file_path}')

# Example usage
input_folder = '/content/drive/MyDrive/Asthma Detection Dataset Version 2/healthy'  # Path to your input audio folder
output_folder = '/content/drive/MyDrive/preprocessAudio/healthy'  # Path to save the processed audio

# Process all audio files in the input folder with desired parameters
process_audio_folder(input_folder, output_folder, stretch_rate=1.5, noise_level=0.005)
# Out:
# Processed P15Healthy65S.wav and saved to /content/drive/MyDrive/preprocessAudio/healthy/processed_P15Healthy65S.wav
# Processed P14Healthy47S.wav and saved to /content/drive/MyDrive/preprocessAudio/healthy/processed_P14Healthy47S.wav
# Processed P17Healthy71S.wav and saved to /content/drive/MyDrive/preprocessAudio/healthy/processed_P17Healthy71S.wav
# Processed P17Healthy35S.wav and saved to /content/drive/MyDrive/preprocessAudio/healthy/processed_P17Healthy35S.wav
# Processed P14Healthy28S.wav and saved to /content/drive/MyDrive/preprocessAudio/healthy/processed_P14Healthy28S.wav
# Processed P14Healthy53S.wav and saved to /content/drive/MyDrive/preprocessAudio/healthy/processed_P14Healthy53S.wav
# Processed P19Healthy47S.wav and saved to /content/drive/MyDrive/preprocessAudio/healthy/processed_P19Healthy47S.wav
# Processed P12Healthy67S.wav and saved to /content/drive/MyDrive/preprocessAudio/healthy/processed_P12Healthy67S.wav
# Processed P10Healthy10S.wav and saved to /content/drive/MyDrive/preprocessAudio/healthy/processed_
.wav and saved to /content/drive/MyDrive/preprocessAudio/healthy/processed_P6Healthy34S.wav
# Processed P9Healthy22S.wav and saved to /content/drive/MyDrive/preprocessAudio/healthy/processed_P9Healthy22S.wav

# %%
import librosa
import numpy as np
import soundfile as sf  # For saving the modified audio

def process_audio(file_path, output_path, stretch_rate=1.0, pitch_shift_steps=0, noise_level=0.0):
    # Load the audio file
    y, sr = librosa.load(file_path, sr=None)  # Load with original sample rate

    # Time Stretching
    if stretch_rate != 1.0:
        y = librosa.effects.time_stretch(y, rate=stretch_rate)  # Use 'rate' keyword argument



    # Adding Noise
    if noise_level > 0.0:
        noise = np.random.randn(len(y)) * noise_level  # Generate Gaussian noise
        y = y + noise  # Add noise to the audio signal

    # Save the processed audio
    sf.write(output_path, y, sr)

def process_audio_folder(input_folder, output_folder, stretch_rate=1.0, noise_level=0.0):
    # Create the output folder if it does not exist
    os.makedirs(output_folder, exist_ok=True)

    # Process each audio file in the input folder
    for filename in os.listdir(input_folder):
        if filename.endswith('.wav'):  # Process only WAV files
            input_file_path = os.path.join(input_folder, filename)
            output_file_path = os.path.join(output_folder, f'processed_{filename}')
            process_audio(input_file_path, output_file_path, stretch_rate,  noise_level)
            print(f'Processed {filename} and saved to {output_file_path}')

# Example usage
input_folder = '/content/drive/MyDrive/Asthma Detection Dataset Version 2/pneumonia'  # Path to your input audio folder
output_folder = '/content/drive/MyDrive/preprocessAudio/pneumonia'  # Path to save the processed audio

# Process all audio files in the input folder with desired parameters
process_audio_folder(input_folder, output_folder, stretch_rate=1.5, noise_level=0.005)
# Out:
# Processed P10Pneumonia80J.wav and saved to /content/drive/MyDrive/preprocessAudio/pneumonia/processed_P10Pneumonia80J.wav
# Processed P13Pneumonia33Z.wav and saved to /content/drive/MyDrive/preprocessAudio/pneumonia/processed_P13Pneumonia33Z.wav
# Processed P12Pneumonia59Q.wav and saved to /content/drive/MyDrive/preprocessAudio/pneumonia/processed_P12Pneumonia59Q.wav
# Processed P11Pneumonia98J.wav and saved to /content/drive/MyDrive/preprocessAudio/pneumonia/processed_P11Pneumonia98J.wav
# Processed P10Pneumonia97B.wav and saved to /content/drive/MyDrive/preprocessAudio/pneumonia/processed_P10Pneumonia97B.wav
# Processed P12Pneumonia45B.wav and saved to /content/drive/MyDrive/preprocessAudio/pneumonia/processed_P12Pneumonia45B.wav
# Processed P12Pneumonia44H.wav and saved to /content/drive/MyDrive/preprocessAudio/pneumonia/processed_P12Pneumonia44H.wav
# Processed P12Pneumonia97E.wav and saved to /content/drive/MyDrive/preprocessAudio/pneumonia/processed_P12Pneumonia97E.wav
# Processed P12Pneumonia23P.wav and saved to /content/drive/MyDrive/preprocessAudio/pneumonia/processed_P12Pneumonia23P.wav
# Processed P10Pneumonia88R.wav and saved to /content/drive/MyDrive/preprocessAudio/pneumonia/processed_P10Pneumonia88R.wav
# Processed P10Pneumonia52A.wav and saved to /content/drive/MyDrive/preprocessAudio/pneumonia/processed_P10Pneumonia52A.wav
# Processed P13Pneumonia26N.wav and saved to /content/drive/MyDrive/preprocessAudio/pneumonia/processed_P13Pneumonia26N.wav
# Processed P13Pneumonia20R.wav and saved to /content/drive/MyDrive/preprocessAudio/pneumonia/processed_P13Pneumonia20R.wav
# Processed P11Pneumonia58A.wav and saved to /content/drive/MyDrive/preprocessAudio/pneumonia/processed_P11Pneumonia58A.wav
# Processed P12Pneumonia46L.wav and saved to /content/drive/MyDrive/preprocessAudio/pneumonia/processed_P12Pneumonia46L.wav
# Processed P10Pneumonia93W.wav and saved to /content/drive/MyDrive/preprocessAudio/pneumonia/processed_P10Pneumonia93W.wav
# Processed P10Pneumonia73G.wav and saved to /content/drive/MyDrive/preprocessAudio/pneumonia/processed_P10Pneumonia73G.wav
# Processed P11Pneumonia12W.wav and saved to /content/drive/MyDrive/preprocessAudio/pneumonia/processed_P11Pneumonia12W.wav
# Processed P11Pneumonia41N.wav and saved to /content/drive/MyDrive/preprocessAudio/pneumonia/processed_P11Pneumonia41N.wav
# Processed P11Pneumonia65P.wav and saved to /content/drive/MyDrive/preprocessAudio/pneumonia/processed_P11Pneumonia65P.wav
# Processed P11Pneumonia18T.wav and saved to /content/drive/MyDrive/preprocessAudio/pneumonia/processed_P11Pneumonia18T.wav
# Processed P17Pneumonia63G.wav and saved to /content/drive/MyDrive/preprocessAudio/pneumonia/processed_P17Pneumonia63G.wav
# Processed P15Pneumonia39Y.wav and saved to /content/drive/MyDrive/preprocessAudio/pneumonia/processed_P15Pneumonia39Y.wav
# Processed P14Pneumonia40M.wav and saved to /content/drive/MyDrive/preprocessAudio/pneumonia/processed_P14Pneumonia40M.wav
# Processed P20Pneumonia27V.wav and saved to /content/drive/MyDrive/preprocessAudio/pneumonia/processed_P20Pneumonia27V.wav
# Processed P20Pneumonia37V.wav and saved to /content/drive/MyDrive/preprocessAudio/pneumonia/processed_P20Pneumonia37V.wav
# Processed P16Pneumonia80G.wav and saved to /content/drive/MyDrive/preprocessAudio/pneumonia/processed_